# %% [markdown]
# <a href="https://colab.research.google.com/github/VIGNESHS2005/filpkart-sales-dataset-/blob/main/amazon_fires1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv("/content/amazon_fires.csv",encoding="ISO-8859-1")

# %% [markdown]
# #data cleaning

# %%
# step=2 removing the duplicate data value
df1.drop_duplicates(inplace=True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6424 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         6424 non-null   int64
#  1   month        6424 non-null   object
#  2   state        6424 non-null   object
#  3   no_of_fores  6292 non-null   object
#  4   date         6424 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 301.1+ KB

# %%
# data cleaning
# rename the columns
d={'ano':'year','mes':'month','estado':'state','numero':'no_of_fores','encontro':'date'}
df1.rename(columns=d,inplace=True)
df1
# Out:
#       year     month      state no_of_fores      date
# 0     1998   Janeiro       Acre     0 Fires  1/1/1998
# 1     1999   Janeiro       Acre     0 Fires  1/1/1999
# 2     2000   Janeiro       Acre     0 Fires  1/1/2000
# 3     2001   Janeiro       Acre     0 Fires  1/1/2001
# 4     2002   Janeiro       Acre     0 Fires  1/1/2002
# ...    ...       ...        ...         ...       ...
# 6449  2012  Dezembro  Tocantins         128  1/1/2012
# 6450  2013  Dezembro  Tocantins          85  1/1/2013
# 6451  2014  Dezembro  Tocantins         223  1/1/2014
# 6452  2015  Dezembro  Tocantins         373  1/1/2015
# 6453  2016  Dezembro  Tocantins         119  1/1/2016
#
# [6454 rows x 5 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6424 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         6424 non-null   int64
#  1   month        6424 non-null   object
#  2   state        6424 non-null   object
#  3   no_of_fores  6292 non-null   object
#  4   date         6424 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 301.1+ KB

# %%
# step=2 removing the duplicate data value
df1.drop_duplicates(inplace=True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6424 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         6424 non-null   int64
#  1   month        6424 non-null   object
#  2   state        6424 non-null   object
#  3   no_of_fores  6292 non-null   object
#  4   date         6424 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 301.1+ KB
