# %% [markdown]
# <a href="https://colab.research.google.com/github/VIGNESHS2005/filpkart-sales-dataset-/blob/main/dataanalyst_loc1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc[5,['Pclass','Name','Sex']]
# Out:
# Pclass                   3
# Name      Moran, Mr. James
# Sex                   male
# Name: 5, dtype: object

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/content/flipkart_sales (1).csv')
df
# Out:
#      Order ID      Product Name        Category  Price (INR)  Quantity Sold  \
# 0    ORD00001  Educational Book           Books     49069.56              2
# 1    ORD00002             Jeans        Clothing     12755.85              4
# 2    ORD00003        Face Cream          Beauty     11092.19              4
# 3    ORD00004        Smartwatch     Electronics     32657.81              1
# 4    ORD00005      Cookware Set  Home & Kitchen     26590.08              3
# ..        ...               ...             ...          ...            ...
# 995  ORD00996        Smartphone     Electronics     28995.81              3
# 996  ORD00997           Perfume          Beauty     32799.51              2
# 997  ORD00998        Face Cream          Beauty     40840.80              1
# 998  ORD00999      Cookware Set  Home & Kitchen     34741.79              4
# 999  ORD01000        Table Lamp  Home & Kitchen     16698.12              4
#
# ...

# %%
df.loc[5,['Product Name','Price (INR)']]
# Out:
# Product Name    Mixer Grinder
# Price (INR)          10475.03
# Name: 5, dtype: object

# %%
print(df.columns)
# Out:
# Index(['Order ID', 'Product Name', 'Category', 'Price (INR)', 'Quantity Sold',
#        'Total Sales (INR)', 'Order Date', 'Payment Method', 'Customer Rating'],
#       dtype='object')

# %%
df.loc[5,['Product Name','Category','Quantity Sold','Order Date']]
# Out:
# Product Name      Mixer Grinder
# Category         Home & Kitchen
# Quantity Sold                 2
# Order Date           2024-10-22
# Name: 5, dtype: object

# %%
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.loc[[5,10,12,19],['Product Name','Price (INR)','Total Sales (INR)']]
# Out:
#         Product Name  Price (INR)  Total Sales (INR)
# 5      Mixer Grinder     10475.03           20950.06
# 10           Perfume     46409.57          232047.85
# 12  Educational Book      6670.82           33354.10
# 19           T-Shirt     32565.77          162828.85

# %%
df.loc[[5,10,12,19],['Product Name','Quantity Sold','Payment Method']]
# Out:
#         Product Name  Quantity Sold Payment Method
# 5      Mixer Grinder              2         Wallet
# 10           Perfume              5            UPI
# 12  Educational Book              5            COD
# 19           T-Shirt              5            COD

# %%
df.iloc[0:11:2,0::2]
# Out:
#     Order ID        Category  Quantity Sold  Order Date  Customer Rating
# 0   ORD00001           Books              2  2024-09-12              3.5
# 2   ORD00003          Beauty              4  2024-05-18              4.4
# 4   ORD00005  Home & Kitchen              3  2024-12-27              3.1
# 6   ORD00007        Clothing              3  2024-07-04              2.0
# 8   ORD00009        Clothing              2  2025-01-18              2.6
# 10  ORD00011          Beauty              5  2025-02-08              2.3

# %%
df.iloc[0:11:2,0::3]
# Out:
#     Order ID  Price (INR)  Order Date
# 0   ORD00001     49069.56  2024-09-12
# 2   ORD00003     11092.19  2024-05-18
# 4   ORD00005     26590.08  2024-12-27
# 6   ORD00007     38647.72  2024-07-04
# 8   ORD00009      1987.39  2025-01-18
# 10  ORD00011     46409.57  2025-02-08
